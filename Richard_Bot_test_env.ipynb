# %%
# Imports
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import random
import time as t
import re
import sqlite3
from config import email
from config import password

# %%
con = sqlite3.connect('fighter_database.db')
cur = con.cursor()
cur.execute(''' SELECT count(name) FROM sqlite_master WHERE type='table' AND name='fighters' ''')

# %%
# Create table
if cur.fetchone()[0]==1 : {
	print('Table exists.')
}
else:
    cur.execute('''CREATE TABLE fighters
               (name TEXT NOT NULL UNIQUE, kills INTEGER, deaths INTEGER, ratio REAL)''')
# Out:
# Table exists.

# %%
# Set the executable path and initialize Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 103.0.5060
# Get LATEST chromedriver version for 103.0.5060 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/103.0.5060.53/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\rab_b\.wdm\drivers\chromedriver\win32\103.0.5060.53]

# %%
#login to saltybet hit enter and wait 3 seconds for page to load
url = 'https://www.saltybet.com/authenticate?signin=1'
browser.visit(url)
#browser.find_by_id('email').click()
browser.find_by_id("email").fill(f'{email}')
browser.find_by_id("pword").fill(f'{password}\n')
# ActionChains(browser).move_to_element(text_input).send_keys_to_element(text_input, "mdicky93@gmail.com").perform()
t.sleep(3)

# %%
def update_fighters(player1_text, player2_text):
    print('update start')
    winner_banner = browser.find_by_id('betstatus').value
    print(winner_banner)
    red_win = re.search('Payouts to Team Red', winner_banner)
    print(red_win)
    blue_win = re.search('Payouts to Team Blue', winner_banner)
    print(blue_win)
    print(f'red was {player1_text}  blue was {player2_text}')
    if red_win != None:
        print('red won')
        cur.execute(' SELECT * from fighters WHERE name=?',(player1_text,))
        if cur.fetchone()==None:
            cur.execute("INSERT INTO fighters VALUES (?,?,?,?)", (player1_text,1,0,1.0))
            red_ratio = 1.0
        else:
            cur.execute(' SELECT kills, deaths from fighters WHERE name=?',(player1_text,))
            c_wins, c_loss = cur.fetchone()
            try:
                red_ratio = (c_wins + 1) / c_loss
            except ZeroDivisionError:
                red_ratio = (c_wins + 1)
            cur.execute('UPDATE fighters SET kills = ?, ratio = ? WHERE name = ?',(c_wins+1, red_ratio, player1_text))
        cur.execute(''' SELECT * from fighters WHERE name=?''',(player2_text,))    
        if cur.fetchone()==None:   
            cur.execute("INSERT INTO fighters VALUES (?,?,?,?)", (player2_text,0,1,0.0))
            blue_ratio = 0.0
        else:
            cur.execute(' SELECT kills, deaths from fighters WHERE name=?',(player2_text,))
            c_wins, c_loss = cur.fetchone()
            blue_ratio = c_wins / (c_loss + 1)
            cur.execute('UPDATE fighters SET deaths = ? , ratio = ? WHERE name = ?',(c_loss+1, blue_ratio, player2_text))
    elif blue_win != None:
        print('blue won')
        cur.execute(' SELECT * from fighters WHERE name=?',(player2_text,))
        if cur.fetchone()==None:
            cur.execute("INSERT INTO fighters VALUES (?,?,?,?)",(player2_text,1,0,1.0))
            blue_ratio = 1.0
        else:
            cur.execute(' SELECT kills, deaths from fighters WHERE name=?',(player2_text,))
            c_wins, c_loss = cur.fetchone()
            try:
                blue_ratio = (c_wins + 1) / c_loss
            except ZeroDivisionError:
                blue_ratio = (c_wins + 1)
            cur.execute('UPDATE fighters SET kills = ?, ratio = ? WHERE name = ?',(c_wins+1, blue_ratio, player2_text))
        cur.execute(''' SELECT * from fighters WHERE name=?''',(player1_text,))    
        if cur.fetchone()==None:   
            cur.execute("INSERT INTO fighters VALUES (?,?,?,?)",(player1_text,0,1,0.0))
        else:
            cur.execute(' SELECT kills, deaths from fighters WHERE name=?',(player1_text,))
            c_wins, c_loss = cur.fetchone()
            red_ratio = c_wins / (c_loss + 1)
            cur.execute('UPDATE fighters SET deaths = ? , ratio = ? WHERE name = ?',(c_loss+1, red_ratio, player1_text))
    con.commit()
    print('fighters updated')

# %%
def bet_loop(player1_text,player2_text, exhib_marker):
    print('loop start')
    #check to make sure the bet was accepted before moving on
    betconfirm = browser.is_element_present_by_id('betconfirm')
    if betconfirm == True:
        #don't want to constantly keep clicking random until match starts. bet confirm appears once you bet and disappears upon match start.
        i = 0
        while betconfirm == True:
            if i == 0:
                print('bet confirmed')
            betconfirm = browser.is_element_present_by_id('betconfirm')
            t.sleep(5)
            i += 1
        #looking for the arrow in the odds section after match starts as an idicator that match is ongoing.
        i = 0
        while browser.find_by_id('betstatus').value == 'Bets are OPEN!' or browser.find_by_id('betstatus').value == 'Bets are locked until the next match.':
            t.sleep(0.2)
            if i == 0:
                print('in a match')
            i += 1
        while browser.find_by_id('betstatus').value == "":
            t.sleep(0.10)
        while browser.find_by_id('betstatus').value == None:
            t.sleep(0.10)
        print('fighters to be updated')
        if exhib_marker == 1:
            return
        else:
            update_fighters(player1_text,player2_text)
    else:
        print('bet not confirmed')
        t.sleep(2)
    print('loop complete')

# %%
def bet_who(bet_amount, mo_money = ""):
    print('begin selection')
    player1 = browser.find_by_id('player1')
    player1_text = browser.find_by_id('player1').value
    # print(player1_text)
    player2 = browser.find_by_id('player2')
    player2_text = browser.find_by_id('player2').value
    # print(player2_text)
    cur.execute(' SELECT * from fighters WHERE name=?',(player1_text,))
    if cur.fetchone()==None:
        print('fighter 1 not found')
        fighter1_present=0
    else:
        print('fighter 1 found')
        fighter1_present=1
    cur.execute(' SELECT * from fighters WHERE name=?',(player2_text,))
    if cur.fetchone()==None:
        print('fighter 2 not found')
        fighter2_present=0
    else:
        print('fighter 2 found')
        fighter2_present=1
    if fighter1_present == 0 and fighter2_present == 0:
        # random fight.
        try:
            #had to use a try except here as clicking when nothing is there causes errors. I'm sure this can be written better. this finds and clicks all in button
            if mo_money == "":
                allin=browser.find_by_id(bet_amount)
                allin.click()
                t.sleep(0.2)
            else:
                browser.find_by_id('wager').fill(mo_money)
            #random click of red or blue.
            coinflip=random.choice([0,1])
            if coinflip == 1:
                player2.click()
                print('bet on blue')
                t.sleep(0.2)
            else:
                player1.click()
                print('bet on red')
                t.sleep(0.2)
            print('go to loop')
            exhib_marker = 0
            bet_loop(player1_text,player2_text, exhib_marker)
        except:
            t.sleep(1)
            # probably need to define a function for random then put here to retry random() after sleep
    elif (fighter1_present == 1 and fighter2_present == 0) or (fighter1_present == 0 and fighter2_present == 1):
        try:
            if mo_money == "":
                allin=browser.find_by_id(bet_amount)
                allin.click()
                t.sleep(0.2)
            else:
                browser.find_by_id('wager').fill(mo_money)
            cur.execute(' SELECT * from fighters WHERE name=?',(player1_text,))
            if cur.fetchone()==None:
                cur.execute(' SELECT ratio from fighters WHERE name=?',(player2_text,))
                ratio = cur.fetchone()[0]
                print(f'player 2 ratio is {ratio}')
                if ratio < 1.0:
                    player1.click()
                    print('bet on red')
                    t.sleep(0.2)
                else:
                    player2.click()
                    print('bet on blue')
                    t.sleep(0.2)
            else:
                cur.execute(' SELECT ratio from fighters WHERE name=?',(player1_text,))
                ratio = cur.fetchone()[0]
                print(f'player 1 ratio is {ratio}')
                if ratio < 1.0:
                    player2.click()
                    print('bet on blue')
                    t.sleep(0.2)
                else:
                    player1.click()
                    print('bet on red')
                    t.sleep(0.2)
            print('go to loop')
            exhib_marker = 0
            bet_loop(player1_text,player2_text, exhib_marker)
        except:
            t.sleep(1)
        # bet on fighter with stats if ratio >0.5 else bet on unknown
    elif fighter1_present == 1 and fighter2_present == 1:
        # bet on fighter with higher win loss ratio
        try:
            if mo_money == "":
                allin=browser.find_by_id(bet_amount)
                allin.click()
                t.sleep(0.2)
            else:
                browser.find_by_id('wager').fill(mo_money)
            cur.execute(''' SELECT ratio from fighters WHERE name=?''',(player1_text,)) 
            red_ratio = cur.fetchone()[0]
            print(f'red ratio is {red_ratio}')
            cur.execute(''' SELECT ratio from fighters WHERE name=?''',(player1_text,))
            blue_ratio = cur.fetchone()[0]
            print(f'blue ratio is {blue_ratio}')
            if red_ratio >= blue_ratio:
                player1.click()
                print('bet on red')
            else:
                player2.click()
                print('bet on blue')
            print('go to loop')
            exhib_marker = 0
            bet_loop(player1_text,player2_text, exhib_marker)
        except:
            t.sleep(1)
    print('finish selection')

# %%
def exhib_bet():
    player1 = browser.find_by_id('player1')
    player1_text = browser.find_by_id('player1').value
    player2 = browser.find_by_id('player2')
    player2_text = browser.find_by_id('player2').value
    browser.find_by_id('wager').fill('1000')
    coinflip=random.choice([0,1])
    if coinflip == 1:
        player2.click()
        print('bet on blue')
        t.sleep(0.2)
    else:
        player1.click()
        print('bet on red')
        t.sleep(0.2)
    print('go to loop')
    t.sleep(0.2)
    exhib_marker = 1
    bet_loop(player1_text,player2_text, exhib_marker)

# %%
u_input = int(input('How many matches would you like to run?'))
while browser.find_by_id('betstatus').value != 'Bets are OPEN!':
    t.sleep(5)
random.seed()
for i in range(u_input):
    while browser.find_by_id('betstatus').value != 'Bets are OPEN!':
        t.sleep(1)
    footer_text = browser.evaluate_script("document.getElementById('footer-alert').textContent")
    exhib_time = re.search('exhibition', footer_text, re.I)
    #t_time = browser.is_element_present_by_id('tournament-note')
    #used is_element_not instead of is_element_present as it runs almost 2 seconds faster, don't know why.
    t_time = browser.is_element_not_present_by_css('span[class="dollar purpletext"][id="balance"]')
    #if the purple text of balance is present we begin betting
    if t_time == False and int(browser.find_by_id('balance').value.replace(',',"")) <=4000:
        print(f'{i} tournament all in')
        print(browser.find_by_id('balance').value)
        bet_who('interval10')
    elif t_time == False and int(browser.find_by_id('balance').value.replace(',',"")) <=7000:
        print(f'{i} tournament 50 percent')
        print(browser.find_by_id('balance').value)
        bet_who('interval5')
    elif t_time == False and int(browser.find_by_id('balance').value.replace(',',"")) > 7000:
        print(f'{i} tournament 10 percent')
        print(browser.find_by_id('balance').value)
        bet_who('interval1')
    elif exhib_time != None and int(browser.find_by_id('balance').value.replace(',',"")) >=50000:
        print("exhhibition bet")
        print(browser.find_by_id('balance').value)
        exhib_bet()
    elif exhib_time != None and int(browser.find_by_id('balance').value.replace(',',"")) <50000:
        y=0
        while exhib_time != None:
            if y== 0:
                print("exhibition not enough money")
                print(browser.find_by_id('balance').value)
                y += 1
            footer_text = browser.evaluate_script("document.getElementById('footer-alert').textContent")
            exhib_time = re.search('exhibition', footer_text, re.I)
            t.sleep(20)    
    elif int(browser.find_by_css('span[class="dollar"][id="balance"]').value.replace(',',"")) <= 500:
        print(f'{i} regular all in')
        print(browser.find_by_id('balance').value)
        bet_who('interval10')
    elif int(browser.find_by_css('span[class="dollar"][id="balance"]').value.replace(',',"")) <= 1000 :
        print(f'{i} regular half bet')
        print(browser.find_by_id('balance').value)
        bet_who('interval5')
    elif int(browser.find_by_css('span[class="dollar"][id="balance"]').value.replace(',',"")) <= 2000 :
        print(f'{i} regular 30 percent bet')
        print(browser.find_by_id('balance').value)
        bet_who('interval3')
    elif int(browser.find_by_css('span[class="dollar"][id="balance"]').value.replace(',',"")) <= 3000 :
        print(f'{i} regular 20 percent bet')
        print(browser.find_by_id('balance').value)
        bet_who('interval2')
    elif int(browser.find_by_css('span[class="dollar"][id="balance"]').value.replace(',',"")) <= 250000 :
        print(f'{i} regular 10 percent bet')
        print(browser.find_by_id('balance').value)
        bet_who('interval1')
    elif int(browser.find_by_css('span[class="dollar"][id="balance"]').value.replace(',',"")) <= 500000 :
        print(f'{i} regular 25,000 bet')
        print(browser.find_by_id('balance').value)
        bet_who('interval1', "25000")
    else:
        print(f'{i} regular 35,000 bet')
        print(browser.find_by_id('balance').value)
        bet_who('interval1', "35000")
browser.quit()
con.close()
# Out:
# 0 regular 35,000 bet
# 1,161,243
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Amity wins! Payouts to Team Red.
# <re.Match object; span=(12, 31), match='Payouts to Team Red'>
# None
# red was Amity  blue was Usada hikaru
# red won
# fighters updated
# loop complete
# finish selection
# 1 regular 35,000 bet
# 1,126,243
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# King dedede ssbb wins! Payouts to Team Red.
# <re.Match object; span=(23, 42), match='Payouts to Team Red'>
# None
# red was King dedede ssbb  blue was Kirigamine kiriko
# red won
# fighters updated
# loop complete
# finish selection
# 2 regular 35,000 bet
# 1,091,243
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Nanmushi wins! Payouts to Team Blue.
# None
# <re.Match object; span=(15, 35), match='Payouts to Team Blue'>
# red was Marika yamagata  blue was Nanmushi
# blue won
# fighters updated
# loop complete
# finish selection
# 3 regular 35,000 bet
# 1,096,416
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 0.3333333333333333
# blue ratio is 0.3333333333333333
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# George wins! Payouts to Team Red.
# <re.Match object; span=(13, 32), match='Payouts to Team Red'>
# None
# red was George  blue was Kamen rider ghost
# red won
# fighters updated
# loop complete
# finish selection
# 4 regular 35,000 bet
# 1,111,539
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Miyako(coh) wins! Payouts to Team Blue.
# None
# <re.Match object; span=(18, 38), match='Payouts to Team Blue'>
# red was Gyaoslen  blue was Miyako(coh)
# blue won
# fighters updated
# loop complete
# finish selection
# 5 regular 35,000 bet
# 1,171,059
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Ru wins! Payouts to Team Red.
# <re.Match object; span=(9, 28), match='Payouts to Team Red'>
# None
# red was Ru  blue was Kim kaphwan EX3
# red won
# fighters updated
# loop complete
# finish selection
# 6 regular 35,000 bet
# 1,136,059
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Ultron wins! Payouts to Team Red.
# <re.Match object; span=(13, 32), match='Payouts to Team Red'>
# None
# red was Ultron  blue was Misaka mikoto EX2
# red won
# fighters updated
# loop complete
# finish selection
# 7 regular 35,000 bet
# 1,191,333
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 0.0
# blue ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# !!! wins! Payouts to Team Blue.
# None
# <re.Match object; span=(10, 30), match='Payouts to Team Blue'>
# red was Alyssa searrs  blue was !!!
# blue won
# fighters updated
# loop complete
# finish selection
# 8 regular 35,000 bet
# 1,156,333
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Mimikyu wins! Payouts to Team Blue.
# None
# <re.Match object; span=(14, 34), match='Payouts to Team Blue'>
# red was Funny juda  blue was Mimikyu
# blue won
# fighters updated
# loop complete
# finish selection
# 9 regular 35,000 bet
# 1,165,937
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Mango's fox wins! Payouts to Team Red.
# <re.Match object; span=(18, 37), match='Payouts to Team Red'>
# None
# red was Mango's fox  blue was Metalman mvc
# red won
# fighters updated
# loop complete
# finish selection
# 10 regular 35,000 bet
# 1,195,121
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Eternal champion wins! Payouts to Team Red.
# <re.Match object; span=(23, 42), match='Payouts to Team Red'>
# None
# red was Eternal champion  blue was Omega rugal 95-kofm
# red won
# fighters updated
# loop complete
# finish selection
# 11 regular 35,000 bet
# 1,160,121
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 1.0
# blue ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Psionic donald wins! Payouts to Team Blue.
# None
# <re.Match object; span=(21, 41), match='Payouts to Team Blue'>
# red was S_youmu  blue was Psionic donald
# blue won
# fighters updated
# loop complete
# finish selection
# 12 regular 35,000 bet
# 1,125,121
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Fang 0d wins! Payouts to Team Red.
# <re.Match object; span=(14, 33), match='Payouts to Team Red'>
# None
# red was Fang 0d  blue was Kung fu men
# red won
# fighters updated
# loop complete
# finish selection
# 13 regular 35,000 bet
# 1,142,512
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Iroquois pliskin wins! Payouts to Team Blue.
# None
# <re.Match object; span=(23, 43), match='Payouts to Team Blue'>
# red was Robocop  blue was Iroquois pliskin
# blue won
# fighters updated
# loop complete
# finish selection
# 14 regular 35,000 bet
# 1,107,512
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Teddie wins! Payouts to Team Red.
# <re.Match object; span=(13, 32), match='Payouts to Team Red'>
# None
# red was Teddie  blue was Cyborg_t-8p
# red won
# fighters updated
# loop complete
# finish selection
# 15 regular 35,000 bet
# 1,138,484
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Honoka wins! Payouts to Team Blue.
# None
# <re.Match object; span=(13, 33), match='Payouts to Team Blue'>
# red was Arina  blue was Honoka
# blue won
# fighters updated
# loop complete
# finish selection
# 16 regular 35,000 bet
# 1,157,431
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Jones ex wins! Payouts to Team Blue.
# None
# <re.Match object; span=(15, 35), match='Payouts to Team Blue'>
# red was Mr_shihan_ky  blue was Jones ex
# blue won
# fighters updated
# loop complete
# finish selection
# 17 regular 35,000 bet
# 1,122,431
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Mahoko wins! Payouts to Team Blue.
# None
# <re.Match object; span=(13, 33), match='Payouts to Team Blue'>
# red was Kuwabara  blue was Mahoko
# blue won
# fighters updated
# loop complete
# finish selection
# 18 regular 35,000 bet
# 1,087,431
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Tia langray wins! Payouts to Team Red.
# <re.Match object; span=(18, 37), match='Payouts to Team Red'>
# None
# red was Tia langray  blue was Coil
# red won
# fighters updated
# loop complete
# finish selection
# 19 regular 35,000 bet
# 1,052,431
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Mr.satan EX3 wins! Payouts to Team Red.
# <re.Match object; span=(19, 38), match='Payouts to Team Red'>
# None
# red was Mr.satan EX3  blue was Yuri-rotd_ttsplus
# red won
# fighters updated
# loop complete
# finish selection
# 20 regular 35,000 bet
# 1,017,431
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Tomitake jirou wins! Payouts to Team Red.
# <re.Match object; span=(21, 40), match='Payouts to Team Red'>
# None
# red was Tomitake jirou  blue was Sim young gradation
# red won
# fighters updated
# loop complete
# finish selection
# 21 regular 35,000 bet
# 1,089,040
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Sodom sfa wins! Payouts to Team Blue.
# None
# <re.Match object; span=(16, 36), match='Payouts to Team Blue'>
# red was Kou EX3  blue was Sodom sfa
# blue won
# fighters updated
# loop complete
# finish selection
# 22 regular 35,000 bet
# 1,054,040
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Adelheid xiii wins! Payouts to Team Blue.
# None
# <re.Match object; span=(20, 40), match='Payouts to Team Blue'>
# red was Cci xiangfei  blue was Adelheid xiii
# blue won
# fighters updated
# loop complete
# finish selection
# 23 regular 35,000 bet
# 1,078,503
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Sakura kyoko wins! Payouts to Team Blue.
# None
# <re.Match object; span=(19, 39), match='Payouts to Team Blue'>
# red was Raydric_and_archer  blue was Sakura kyoko
# blue won
# fighters updated
# loop complete
# finish selection
# 24 regular 35,000 bet
# 1,092,707
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Boring sdk mukurou wins! Payouts to Team Red.
# <re.Match object; span=(25, 44), match='Payouts to Team Red'>
# None
# red was Boring sdk mukurou  blue was Zen&rei
# red won
# fighters updated
# loop complete
# finish selection
# 25 regular 35,000 bet
# 1,057,707
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Shiro_kishi wins! Payouts to Team Red.
# <re.Match object; span=(18, 37), match='Payouts to Team Red'>
# None
# red was Shiro_kishi  blue was Twintail
# red won
# fighters updated
# loop complete
# finish selection
# 26 regular 35,000 bet
# 1,096,808
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Masked rider hibiki(emanon) wins! Payouts to Team Blue.
# None
# <re.Match object; span=(34, 54), match='Payouts to Team Blue'>
# red was Shadow2  blue was Masked rider hibiki(emanon)
# blue won
# fighters updated
# loop complete
# finish selection
# 27 regular 35,000 bet
# 1,061,808
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Preposterous cirno wins! Payouts to Team Blue.
# None
# <re.Match object; span=(25, 45), match='Payouts to Team Blue'>
# red was Otona suzu  blue was Preposterous cirno
# blue won
# fighters updated
# loop complete
# finish selection
# 28 regular 35,000 bet
# 1,069,765
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Uesugi kensin EX G wins! Payouts to Team Red.
# <re.Match object; span=(25, 44), match='Payouts to Team Red'>
# None
# red was Uesugi kensin EX G  blue was Asher
# red won
# fighters updated
# loop complete
# finish selection
# 29 regular 35,000 bet
# 1,034,765
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.5
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Baseball pooh wins! Payouts to Team Blue.
# None
# <re.Match object; span=(20, 40), match='Payouts to Team Blue'>
# red was Chun-li jj  blue was Baseball pooh
# blue won
# fighters updated
# loop complete
# finish selection
# 30 regular 35,000 bet
# 1,048,735
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Revlius wins! Payouts to Team Blue.
# None
# <re.Match object; span=(14, 34), match='Payouts to Team Blue'>
# red was King-kofm  blue was Revlius
# blue won
# fighters updated
# loop complete
# finish selection
# 31 regular 35,000 bet
# 1,154,037
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Jason voorhees wins! Payouts to Team Blue.
# None
# <re.Match object; span=(21, 41), match='Payouts to Team Blue'>
# red was Ruili  blue was Jason voorhees
# blue won
# fighters updated
# loop complete
# finish selection
# 32 regular 35,000 bet
# 1,160,911
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Kanon del geminis wins! Payouts to Team Blue.
# None
# <re.Match object; span=(24, 44), match='Payouts to Team Blue'>
# red was Panda genma  blue was Kanon del geminis
# blue won
# fighters updated
# loop complete
# finish selection
# 33 regular 35,000 bet
# 1,247,986
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Popuko chitosegaoka as wins! Payouts to Team Red.
# <re.Match object; span=(29, 48), match='Payouts to Team Red'>
# None
# red was Popuko chitosegaoka as  blue was Beelzebub
# red won
# fighters updated
# loop complete
# finish selection
# 34 regular 35,000 bet
# 1,212,986
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Sayia-f wins! Payouts to Team Red.
# <re.Match object; span=(14, 33), match='Payouts to Team Red'>
# None
# red was Sayia-f  blue was Akatsuki hm
# red won
# fighters updated
# loop complete
# finish selection
# 35 regular 35,000 bet
# 1,177,986
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 0.0
# blue ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Dougster wins! Payouts to Team Red.
# <re.Match object; span=(15, 34), match='Payouts to Team Red'>
# None
# red was Dougster  blue was Vanilla gouken
# red won
# fighters updated
# loop complete
# finish selection
# 36 regular 35,000 bet
# 1,189,544
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Thanos mvc2 wins! Payouts to Team Blue.
# None
# <re.Match object; span=(18, 38), match='Payouts to Team Blue'>
# red was Mech.hisui 404  blue was Thanos mvc2
# blue won
# fighters updated
# loop complete
# finish selection
# 37 regular 35,000 bet
# 1,194,658
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 2.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Durian wins! Payouts to Team Red.
# <re.Match object; span=(13, 32), match='Payouts to Team Red'>
# None
# red was Durian  blue was Sagastick negnin
# red won
# fighters updated
# loop complete
# finish selection
# 38 regular 35,000 bet
# 1,244,763
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 2.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Utagai_san wins! Payouts to Team Blue.
# None
# <re.Match object; span=(17, 37), match='Payouts to Team Blue'>
# red was Smash bros. mario  blue was Utagai_san
# blue won
# fighters updated
# loop complete
# finish selection
# 39 regular 35,000 bet
# 1,209,763
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Albert wesker wins! Payouts to Team Blue.
# None
# <re.Match object; span=(20, 40), match='Payouts to Team Blue'>
# red was Super hornet  blue was Albert wesker
# blue won
# fighters updated
# loop complete
# finish selection
# 40 regular 35,000 bet
# 1,174,763
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Special-a strider hien wins! Payouts to Team Blue.
# None
# <re.Match object; span=(29, 49), match='Payouts to Team Blue'>
# red was Silver the hedgehog  blue was Special-a strider hien
# blue won
# fighters updated
# loop complete
# finish selection
# 41 regular 35,000 bet
# 1,286,807
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Raiden 512e1 wins! Payouts to Team Red.
# <re.Match object; span=(19, 38), match='Payouts to Team Red'>
# None
# red was Raiden 512e1  blue was Kamen rider kabuto
# red won
# fighters updated
# loop complete
# finish selection
# 42 regular 35,000 bet
# 1,251,807
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Faust wins! Payouts to Team Red.
# <re.Match object; span=(12, 31), match='Payouts to Team Red'>
# None
# red was Faust  blue was Kos-mos
# red won
# fighters updated
# loop complete
# finish selection
# 43 regular 35,000 bet
# 1,289,005
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Samwell han wins! Payouts to Team Blue.
# None
# <re.Match object; span=(18, 38), match='Payouts to Team Blue'>
# red was Dark warrior 2  blue was Samwell han
# blue won
# fighters updated
# loop complete
# finish selection
# 44 regular 35,000 bet
# 1,254,005
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Trigger ex wins! Payouts to Team Red.
# <re.Match object; span=(17, 36), match='Payouts to Team Red'>
# None
# red was Trigger ex  blue was Goku el dios excelente
# red won
# fighters updated
# loop complete
# finish selection
# 45 regular 35,000 bet
# 1,259,165
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Golgotha wins! Payouts to Team Blue.
# None
# <re.Match object; span=(15, 35), match='Payouts to Team Blue'>
# red was Hitorisibai-san  blue was Golgotha
# blue won
# fighters updated
# loop complete
# finish selection
# 46 regular 35,000 bet
# 1,224,165
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Italian juda wins! Payouts to Team Blue.
# None
# <re.Match object; span=(19, 39), match='Payouts to Team Blue'>
# red was Aioros de sagitario  blue was Italian juda
# blue won
# fighters updated
# loop complete
# finish selection
# 47 regular 35,000 bet
# 1,312,590
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 2.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Shirai_kuroko wins! Payouts to Team Blue.
# None
# <re.Match object; span=(20, 40), match='Payouts to Team Blue'>
# red was Hon-fu rb2  blue was Shirai_kuroko
# blue won
# fighters updated
# loop complete
# finish selection
# 48 regular 35,000 bet
# 1,322,847
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Minakata moriya wins! Payouts to Team Blue.
# None
# <re.Match object; span=(22, 42), match='Payouts to Team Blue'>
# red was Rakugaki  blue was Minakata moriya
# blue won
# fighters updated
# loop complete
# finish selection
# 49 regular 35,000 bet
# 1,329,393
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Magnus wins! Payouts to Team Red.
# <re.Match object; span=(13, 32), match='Payouts to Team Red'>
# None
# red was Magnus  blue was Akiba
# red won
# fighters updated
# loop complete
# finish selection
# 50 regular 35,000 bet
# 1,389,283
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# C_krizalid wins! Payouts to Team Red.
# <re.Match object; span=(17, 36), match='Payouts to Team Red'>
# None
# red was C_krizalid  blue was Mysterious power
# red won
# fighters updated
# loop complete
# finish selection
# 51 regular 35,000 bet
# 1,409,760
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Anna ex wins! Payouts to Team Blue.
# None
# <re.Match object; span=(14, 34), match='Payouts to Team Blue'>
# red was Ortega ex  blue was Anna ex
# blue won
# fighters updated
# loop complete
# finish selection
# 52 regular 35,000 bet
# 1,374,760
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Omega Woods wins! Payouts to Team Blue.
# None
# <re.Match object; span=(18, 38), match='Payouts to Team Blue'>
# red was Gundam exia  blue was Omega Woods
# blue won
# fighters updated
# loop complete
# finish selection
# 53 regular 35,000 bet
# 1,385,521
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Stronk guy wins! Payouts to Team Blue.
# None
# <re.Match object; span=(17, 37), match='Payouts to Team Blue'>
# red was Vengeful bardock  blue was Stronk guy
# blue won
# fighters updated
# loop complete
# finish selection
# 54 regular 35,000 bet
# 1,350,521
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Kana isolde as wins! Payouts to Team Red.
# <re.Match object; span=(21, 40), match='Payouts to Team Red'>
# None
# red was Kana isolde as  blue was Vritra
# red won
# fighters updated
# loop complete
# finish selection
# 55 regular 35,000 bet
# 1,355,648
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Weakest rugal wins! Payouts to Team Blue.
# None
# <re.Match object; span=(20, 40), match='Payouts to Team Blue'>
# red was Haiji EX8  blue was Weakest rugal
# blue won
# fighters updated
# loop complete
# finish selection
# 56 regular 35,000 bet
# 1,367,339
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Powergirl wins! Payouts to Team Blue.
# None
# <re.Match object; span=(16, 36), match='Payouts to Team Blue'>
# red was Quickman  blue was Powergirl
# blue won
# fighters updated
# loop complete
# finish selection
# 57 regular 35,000 bet
# 1,453,164
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Arima_miyako wins! Payouts to Team Blue.
# None
# <re.Match object; span=(19, 39), match='Payouts to Team Blue'>
# red was Iyo  blue was Arima_miyako
# blue won
# fighters updated
# loop complete
# finish selection
# 58 regular 35,000 bet
# 1,467,581
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Saizo_hattori wins! Payouts to Team Red.
# <re.Match object; span=(20, 39), match='Payouts to Team Red'>
# None
# red was Saizo_hattori  blue was Solid snake EX
# red won
# fighters updated
# loop complete
# finish selection
# 59 regular 35,000 bet
# 1,489,956
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Krillin wins! Payouts to Team Red.
# <re.Match object; span=(14, 33), match='Payouts to Team Red'>
# None
# red was Krillin  blue was Jubilee
# red won
# fighters updated
# loop complete
# finish selection
# 60 tournament all in
# 1,350
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Geisya wins! Payouts to Team Blue.
# None
# <re.Match object; span=(13, 33), match='Payouts to Team Blue'>
# red was Giant baba  blue was Geisya
# blue won
# fighters updated
# loop complete
# finish selection
# 61 tournament 50 percent
# 4,542
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# The binding of isaac wins! Payouts to Team Blue.
# None
# <re.Match object; span=(27, 47), match='Payouts to Team Blue'>
# red was Enegori  blue was The binding of isaac
# blue won
# fighters updated
# loop complete
# finish selection
# 62 tournament 50 percent
# 6,898
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Zekamasi wins! Payouts to Team Blue.
# None
# <re.Match object; span=(15, 35), match='Payouts to Team Blue'>
# red was Ramon 71113  blue was Zekamasi
# blue won
# fighters updated
# loop complete
# finish selection
# 63 tournament 10 percent
# 7,535
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Reak.f wins! Payouts to Team Blue.
# None
# <re.Match object; span=(13, 33), match='Payouts to Team Blue'>
# red was Blockhead enhanced  blue was Reak.f
# blue won
# fighters updated
# loop complete
# finish selection
# 64 tournament 10 percent
# 7,760
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Chako wins! Payouts to Team Red.
# <re.Match object; span=(12, 31), match='Payouts to Team Red'>
# None
# red was Chako  blue was Seiya de pegasus
# red won
# fighters updated
# loop complete
# finish selection
# 65 tournament 50 percent
# 6,984
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 1.0
# blue ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Spitfire_m wins! Payouts to Team Blue.
# None
# <re.Match object; span=(17, 37), match='Payouts to Team Blue'>
# red was Heavyarmscustom  blue was Spitfire_m
# blue won
# fighters updated
# loop complete
# finish selection
# 66 tournament all in
# 3,492
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Fw_gigan wins! Payouts to Team Blue.
# None
# <re.Match object; span=(15, 35), match='Payouts to Team Blue'>
# red was Mast  blue was Fw_gigan
# blue won
# fighters updated
# loop complete
# finish selection
# 67 tournament 50 percent
# 5,074
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Urmnaf bort hyuga wins! Payouts to Team Blue.
# None
# <re.Match object; span=(24, 44), match='Payouts to Team Blue'>
# red was Kusanagi xiii  blue was Urmnaf bort hyuga
# blue won
# fighters updated
# loop complete
# finish selection
# 68 tournament 50 percent
# 5,962
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 1.0
# blue ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# The binding of isaac wins! Payouts to Team Blue.
# None
# <re.Match object; span=(27, 47), match='Payouts to Team Blue'>
# red was Geisya  blue was The binding of isaac
# blue won
# fighters updated
# loop complete
# finish selection
# 69 tournament all in
# 2,981
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 1.0
# blue ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Zekamasi wins! Payouts to Team Red.
# <re.Match object; span=(15, 34), match='Payouts to Team Red'>
# None
# red was Zekamasi  blue was Reak.f
# red won
# fighters updated
# loop complete
# finish selection
# 70 tournament 50 percent
# 5,361
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 1.0
# blue ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Chako wins! Payouts to Team Red.
# <re.Match object; span=(12, 31), match='Payouts to Team Red'>
# None
# red was Chako  blue was Spitfire_m
# red won
# fighters updated
# loop complete
# finish selection
# 71 tournament 10 percent
# 7,556
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 2.0
# blue ratio is 2.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Fw_gigan wins! Payouts to Team Red.
# <re.Match object; span=(15, 34), match='Payouts to Team Red'>
# None
# red was Fw_gigan  blue was Urmnaf bort hyuga
# red won
# fighters updated
# loop complete
# finish selection
# 72 tournament 10 percent
# 7,779
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 3.0
# blue ratio is 3.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Zekamasi wins! Payouts to Team Blue.
# None
# <re.Match object; span=(15, 35), match='Payouts to Team Blue'>
# red was The binding of isaac  blue was Zekamasi
# blue won
# fighters updated
# loop complete
# finish selection
# 73 tournament 10 percent
# 7,001
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 2.0
# blue ratio is 2.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Chako wins! Payouts to Team Red.
# <re.Match object; span=(12, 31), match='Payouts to Team Red'>
# None
# red was Chako  blue was Fw_gigan
# red won
# fighters updated
# loop complete
# finish selection
# 74 tournament 10 percent
# 7,226
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 3.0
# blue ratio is 3.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Zekamasi wins! Payouts to Team Red.
# <re.Match object; span=(15, 34), match='Payouts to Team Red'>
# None
# red was Zekamasi  blue was Chako
# red won
# fighters updated
# loop complete
# finish selection
# exhhibition bet
# 1,463,520
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,462,520
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,461,520
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,460,520
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,459,520
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,458,520
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,457,520
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,456,520
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,456,826
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,456,828
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,465,960
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,466,641
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,466,960
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,470,985
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,469,985
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,468,985
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,471,420
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,470,420
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,471,220
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,470,220
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,469,220
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,468,220
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,469,795
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,468,795
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# exhhibition bet
# 1,467,795
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# 100 regular 35,000 bet
# 1,466,795
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Ash crimson xiii wins! Payouts to Team Red.
# <re.Match object; span=(23, 42), match='Payouts to Team Red'>
# None
# red was Ash crimson xiii  blue was Weiss daemon bride
# red won
# fighters updated
# loop complete
# finish selection
# 101 regular 35,000 bet
# 1,488,651
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# The king of terror wins! Payouts to Team Blue.
# None
# <re.Match object; span=(25, 45), match='Payouts to Team Blue'>
# red was Boss zeedmillenniummon  blue was The king of terror
# blue won
# fighters updated
# loop complete
# finish selection
# 102 regular 35,000 bet
# 1,523,148
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Mr.karate EX2 wins! Payouts to Team Blue.
# None
# <re.Match object; span=(20, 40), match='Payouts to Team Blue'>
# red was Ryoko asakura  blue was Mr.karate EX2
# blue won
# fighters updated
# loop complete
# finish selection
# 103 regular 35,000 bet
# 1,488,148
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Aztec falcon wins! Payouts to Team Red.
# <re.Match object; span=(19, 38), match='Payouts to Team Red'>
# None
# red was Aztec falcon  blue was The blob
# red won
# fighters updated
# loop complete
# finish selection
# 104 regular 35,000 bet
# 1,453,148
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Alicephia wins! Payouts to Team Red.
# <re.Match object; span=(16, 35), match='Payouts to Team Red'>
# None
# red was Alicephia  blue was Deluxe lin
# red won
# fighters updated
# loop complete
# finish selection
# 105 regular 35,000 bet
# 1,462,696
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Belial wins! Payouts to Team Blue.
# None
# <re.Match object; span=(13, 33), match='Payouts to Team Blue'>
# red was Katakura kojuro  blue was Belial
# blue won
# fighters updated
# loop complete
# finish selection
# 106 regular 35,000 bet
# 1,427,696
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Sakura haruno shippuden wins! Payouts to Team Red.
# <re.Match object; span=(30, 49), match='Payouts to Team Red'>
# None
# red was Sakura haruno shippuden  blue was Aioros de sagitario
# red won
# fighters updated
# loop complete
# finish selection
# 107 regular 35,000 bet
# 1,544,543
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Cycloid omega EX wins! Payouts to Team Blue.
# None
# <re.Match object; span=(23, 43), match='Payouts to Team Blue'>
# red was Cyborg t-8p  blue was Cycloid omega EX
# blue won
# fighters updated
# loop complete
# finish selection
# 108 regular 35,000 bet
# 1,598,771
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Lady aozaki wins! Payouts to Team Blue.
# None
# <re.Match object; span=(18, 38), match='Payouts to Team Blue'>
# red was Kanae  blue was Lady aozaki
# blue won
# fighters updated
# loop complete
# finish selection
# 109 regular 35,000 bet
# 1,563,771
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Ridley other m wins! Payouts to Team Blue.
# None
# <re.Match object; span=(21, 41), match='Payouts to Team Blue'>
# red was The freezing august  blue was Ridley other m
# blue won
# fighters updated
# loop complete
# finish selection
# 110 regular 35,000 bet
# 1,568,627
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Jyubei yagyu wins! Payouts to Team Red.
# <re.Match object; span=(19, 38), match='Payouts to Team Red'>
# None
# red was Jyubei yagyu  blue was Tenjou-jin
# red won
# fighters updated
# loop complete
# finish selection
# 111 regular 35,000 bet
# 1,533,627
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Sumo santa wins! Payouts to Team Red.
# <re.Match object; span=(17, 36), match='Payouts to Team Red'>
# None
# red was Sumo santa  blue was Cvtw sol badguy
# red won
# fighters updated
# loop complete
# finish selection
# 112 regular 35,000 bet
# 1,498,627
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Voltz wins! Payouts to Team Red.
# <re.Match object; span=(12, 31), match='Payouts to Team Red'>
# None
# red was Voltz  blue was Super goku
# red won
# fighters updated
# loop complete
# finish selection
# 113 regular 35,000 bet
# 1,519,172
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Shiki tohno wins! Payouts to Team Red.
# <re.Match object; span=(18, 37), match='Payouts to Team Red'>
# None
# red was Shiki tohno  blue was Missingnumber
# red won
# fighters updated
# loop complete
# finish selection
# 114 regular 35,000 bet
# 1,484,172
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Ronove wins! Payouts to Team Blue.
# None
# <re.Match object; span=(13, 33), match='Payouts to Team Blue'>
# red was Yukkuri z-ton 2  blue was Ronove
# blue won
# fighters updated
# loop complete
# finish selection
# 115 regular 35,000 bet
# 1,449,172
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Lf2 - john wins! Payouts to Team Red.
# <re.Match object; span=(17, 36), match='Payouts to Team Red'>
# None
# red was Lf2 - john  blue was Xemnas
# red won
# fighters updated
# loop complete
# finish selection
# 116 regular 35,000 bet
# 1,414,172
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Celesteela wins! Payouts to Team Blue.
# None
# <re.Match object; span=(17, 37), match='Payouts to Team Blue'>
# red was Kay  blue was Celesteela
# blue won
# fighters updated
# loop complete
# finish selection
# 117 regular 35,000 bet
# 1,379,172
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Wong_dong_fei_hung wins! Payouts to Team Red.
# <re.Match object; span=(25, 44), match='Payouts to Team Red'>
# None
# red was Wong_dong_fei_hung  blue was Goyan
# red won
# fighters updated
# loop complete
# finish selection
# 118 regular 35,000 bet
# 1,344,172
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Katakura kojuro_ch wins! Payouts to Team Red.
# <re.Match object; span=(25, 44), match='Payouts to Team Red'>
# None
# red was Katakura kojuro_ch  blue was Deliza
# red won
# fighters updated
# loop complete
# finish selection
# 119 regular 35,000 bet
# 1,309,172
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Suzaku wins! Payouts to Team Red.
# <re.Match object; span=(13, 32), match='Payouts to Team Red'>
# None
# red was Suzaku  blue was Dust of osiris
# red won
# fighters updated
# loop complete
# finish selection
# 120 regular 35,000 bet
# 1,481,310
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Soujiro wins! Payouts to Team Blue.
# None
# <re.Match object; span=(14, 34), match='Payouts to Team Blue'>
# red was Deltarune lancer  blue was Soujiro
# blue won
# fighters updated
# loop complete
# finish selection
# 121 regular 35,000 bet
# 1,486,349
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Margaretha_solin wins! Payouts to Team Red.
# <re.Match object; span=(23, 42), match='Payouts to Team Red'>
# None
# red was Margaretha_solin  blue was Gulcasa
# red won
# fighters updated
# loop complete
# finish selection
# 122 regular 35,000 bet
# 1,451,349
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Zako-dan wins! Payouts to Team Red.
# <re.Match object; span=(15, 34), match='Payouts to Team Red'>
# None
# red was Zako-dan  blue was Tatsuki Arisawa
# red won
# fighters updated
# loop complete
# finish selection
# 123 regular 35,000 bet
# 1,473,133
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# A_decade-ex wins! Payouts to Team Blue.
# None
# <re.Match object; span=(18, 38), match='Payouts to Team Blue'>
# red was Mary  blue was A_decade-ex
# blue won
# fighters updated
# loop complete
# finish selection
# 124 regular 35,000 bet
# 1,480,330
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Destroyous wins! Payouts to Team Red.
# <re.Match object; span=(17, 36), match='Payouts to Team Red'>
# None
# red was Destroyous  blue was Gen shougo
# red won
# fighters updated
# loop complete
# finish selection
# 125 regular 35,000 bet
# 1,559,930
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# G-deadpool wins! Payouts to Team Red.
# <re.Match object; span=(17, 36), match='Payouts to Team Red'>
# None
# red was G-deadpool  blue was Yutosine
# red won
# fighters updated
# loop complete
# finish selection
# 126 regular 35,000 bet
# 1,563,785
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Largefencer_mysty wins! Payouts to Team Blue.
# None
# <re.Match object; span=(24, 44), match='Payouts to Team Blue'>
# red was Charlotte ex  blue was Largefencer_mysty
# blue won
# fighters updated
# loop complete
# finish selection
# 127 regular 35,000 bet
# 1,568,490
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Presea combatir wins! Payouts to Team Red.
# <re.Match object; span=(22, 41), match='Payouts to Team Red'>
# None
# red was Presea combatir  blue was Rassius fomalhaut
# red won
# fighters updated
# loop complete
# finish selection
# 128 regular 35,000 bet
# 1,574,214
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Jinx wins! Payouts to Team Red.
# <re.Match object; span=(11, 30), match='Payouts to Team Red'>
# None
# red was Jinx  blue was Wai
# red won
# fighters updated
# loop complete
# finish selection
# 129 regular 35,000 bet
# 1,590,610
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# No.8 wins! Payouts to Team Red.
# <re.Match object; span=(11, 30), match='Payouts to Team Red'>
# None
# red was No.8  blue was Adelheid EX
# red won
# fighters updated
# loop complete
# finish selection
# 130 regular 35,000 bet
# 1,611,993
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Kanako yasaka EX3 wins! Payouts to Team Red.
# <re.Match object; span=(24, 43), match='Payouts to Team Red'>
# None
# red was Kanako yasaka EX3  blue was Kei shidou EX7
# red won
# fighters updated
# loop complete
# finish selection
# 131 regular 35,000 bet
# 1,622,097
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Ken tek wins! Payouts to Team Blue.
# None
# <re.Match object; span=(14, 34), match='Payouts to Team Blue'>
# red was La mascara  blue was Ken tek
# blue won
# fighters updated
# loop complete
# finish selection
# 132 regular 35,000 bet
# 1,629,992
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Moogle wins! Payouts to Team Red.
# <re.Match object; span=(13, 32), match='Payouts to Team Red'>
# None
# red was Moogle  blue was Maccho
# red won
# fighters updated
# loop complete
# finish selection
# 133 regular 35,000 bet
# 1,594,992
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Pepito EX2 wins! Payouts to Team Blue.
# None
# <re.Match object; span=(17, 37), match='Payouts to Team Blue'>
# red was Rosa_obsn  blue was Pepito EX2
# blue won
# fighters updated
# loop complete
# finish selection
# 134 regular 35,000 bet
# 1,559,992
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 0.0
# blue ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Burnie wins! Payouts to Team Blue.
# None
# <re.Match object; span=(13, 33), match='Payouts to Team Blue'>
# red was Chili n pepper  blue was Burnie
# blue won
# fighters updated
# loop complete
# finish selection
# 135 regular 35,000 bet
# 1,524,992
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Louise f.b.valliere wins! Payouts to Team Blue.
# None
# <re.Match object; span=(26, 46), match='Payouts to Team Blue'>
# red was Fyra noll  blue was Louise f.b.valliere
# blue won
# fighters updated
# loop complete
# finish selection
# 136 regular 35,000 bet
# 1,536,458
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Misuzu wins! Payouts to Team Blue.
# None
# <re.Match object; span=(13, 33), match='Payouts to Team Blue'>
# red was Skull reaper  blue was Misuzu
# blue won
# fighters updated
# loop complete
# finish selection
# 137 regular 35,000 bet
# 1,501,458
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Cyclops wins! Payouts to Team Red.
# <re.Match object; span=(14, 33), match='Payouts to Team Red'>
# None
# red was Cyclops  blue was Akane satomura
# red won
# fighters updated
# loop complete
# finish selection
# 138 regular 35,000 bet
# 1,466,458
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Sakura&karin wins! Payouts to Team Red.
# <re.Match object; span=(19, 38), match='Payouts to Team Red'>
# None
# red was Sakura&karin  blue was Goku pce
# red won
# fighters updated
# loop complete
# finish selection
# 139 regular 35,000 bet
# 1,431,458
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Neko&mech_m wins! Payouts to Team Blue.
# None
# <re.Match object; span=(18, 38), match='Payouts to Team Blue'>
# red was Soda popinski  blue was Neko&mech_m
# blue won
# fighters updated
# loop complete
# finish selection
# 140 regular 35,000 bet
# 1,500,400
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Nakoruru EX3 wins! Payouts to Team Red.
# <re.Match object; span=(19, 38), match='Payouts to Team Red'>
# None
# red was Nakoruru EX3  blue was The italian stallion
# red won
# fighters updated
# loop complete
# finish selection
# 141 regular 35,000 bet
# 1,465,400
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 1.0
# blue ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Kulate kenji wins! Payouts to Team Blue.
# None
# <re.Match object; span=(19, 39), match='Payouts to Team Blue'>
# red was Guillotine gen  blue was Kulate kenji
# blue won
# fighters updated
# loop complete
# finish selection
# 142 regular 35,000 bet
# 1,430,400
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Mad dog wins! Payouts to Team Blue.
# None
# <re.Match object; span=(14, 34), match='Payouts to Team Blue'>
# red was Talon  blue was Mad dog
# blue won
# fighters updated
# loop complete
# finish selection
# 143 regular 35,000 bet
# 1,480,390
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Mecha-king ghidorah wins! Payouts to Team Blue.
# None
# <re.Match object; span=(26, 46), match='Payouts to Team Blue'>
# red was Guilty  blue was Mecha-king ghidorah
# blue won
# fighters updated
# loop complete
# finish selection
# 144 regular 35,000 bet
# 1,496,530
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Tusk ki2 wins! Payouts to Team Blue.
# None
# <re.Match object; span=(15, 35), match='Payouts to Team Blue'>
# red was M.raiga  blue was Tusk ki2
# blue won
# fighters updated
# loop complete
# finish selection
# 145 regular 35,000 bet
# 1,461,530
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 1.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Chuck norris EX wins! Payouts to Team Blue.
# None
# <re.Match object; span=(22, 42), match='Payouts to Team Blue'>
# red was Rare nabeatu  blue was Chuck norris EX
# blue won
# fighters updated
# loop complete
# finish selection
# 146 regular 35,000 bet
# 1,467,376
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# F.o.e._meso wins! Payouts to Team Red.
# <re.Match object; span=(18, 37), match='Payouts to Team Red'>
# None
# red was F.o.e._meso  blue was Houjuu nue
# red won
# fighters updated
# loop complete
# finish selection
# 147 regular 35,000 bet
# 1,483,970
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Animus EX3 wins! Payouts to Team Red.
# <re.Match object; span=(17, 36), match='Payouts to Team Red'>
# None
# red was Animus EX3  blue was Joe swanson
# red won
# fighters updated
# loop complete
# finish selection
# 148 regular 35,000 bet
# 1,448,970
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Youko wins! Payouts to Team Blue.
# None
# <re.Match object; span=(12, 32), match='Payouts to Team Blue'>
# red was Cyber-peacock  blue was Youko
# blue won
# fighters updated
# loop complete
# finish selection
# 149 regular 35,000 bet
# 1,413,970
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 1.0
# blue ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Minecraft goku wins! Payouts to Team Red.
# <re.Match object; span=(21, 40), match='Payouts to Team Red'>
# None
# red was Minecraft goku  blue was Ran horigein
# red won
# fighters updated
# loop complete
# finish selection
# 150 regular 35,000 bet
# 1,461,245
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Sabu EX3 wins! Payouts to Team Blue.
# None
# <re.Match object; span=(15, 35), match='Payouts to Team Blue'>
# red was Lady bow  blue was Sabu EX3
# blue won
# fighters updated
# loop complete
# finish selection
# 151 regular 35,000 bet
# 1,426,245
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 0.0
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Takumi hattori wins! Payouts to Team Blue.
# None
# <re.Match object; span=(21, 41), match='Payouts to Team Blue'>
# red was Kirigamine kiriko  blue was Takumi hattori
# blue won
# fighters updated
# loop complete
# finish selection
# 152 regular 35,000 bet
# 1,467,659
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# God rugal wins! Payouts to Team Blue.
# None
# <re.Match object; span=(16, 36), match='Payouts to Team Blue'>
# red was Rucheca  blue was God rugal
# blue won
# fighters updated
# loop complete
# finish selection
# 153 regular 35,000 bet
# 1,471,421
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Itoshiki nozomu wins! Payouts to Team Blue.
# None
# <re.Match object; span=(22, 42), match='Payouts to Team Blue'>
# red was Mvc2 colossus  blue was Itoshiki nozomu
# blue won
# fighters updated
# loop complete
# finish selection
# 154 regular 35,000 bet
# 1,436,421
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 1.0
# blue ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Krizalid-kofm-kbr wins! Payouts to Team Red.
# <re.Match object; span=(24, 43), match='Payouts to Team Red'>
# None
# red was Krizalid-kofm-kbr  blue was Servant emiya
# red won
# fighters updated
# loop complete
# finish selection
# 155 regular 35,000 bet
# 1,449,146
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Yuudachi kai ni wins! Payouts to Team Blue.
# None
# <re.Match object; span=(22, 42), match='Payouts to Team Blue'>
# red was Yeorin lee  blue was Yuudachi kai ni
# blue won
# fighters updated
# loop complete
# finish selection
# 156 regular 35,000 bet
# 1,414,146
# begin selection
# fighter 1 not found
# fighter 2 found
# player 2 ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Mega robo-len wins! Payouts to Team Red.
# <re.Match object; span=(20, 39), match='Payouts to Team Red'>
# None
# red was Mega robo-len  blue was Salty surfer
# red won
# fighters updated
# loop complete
# finish selection
# 157 regular 35,000 bet
# 1,441,220
# begin selection
# fighter 1 found
# fighter 2 not found
# player 1 ratio is 1.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Judith wins! Payouts to Team Red.
# <re.Match object; span=(13, 32), match='Payouts to Team Red'>
# None
# red was Judith  blue was Mio sakamoto
# red won
# fighters updated
# loop complete
# finish selection
# 158 regular 35,000 bet
# 1,455,188
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Leonhalt domador wins! Payouts to Team Blue.
# None
# <re.Match object; span=(23, 43), match='Payouts to Team Blue'>
# red was Axl x7  blue was Leonhalt domador
# blue won
# fighters updated
# loop complete
# finish selection
# 159 regular 35,000 bet
# 1,420,188
# begin selection
# fighter 1 not found
# fighter 2 not found
# bet on blue
# go to loop
# loop start
# bet confirmed
# in a match
# fighters to be updated
# update start
# Krizalid-i wins! Payouts to Team Red.
# <re.Match object; span=(17, 36), match='Payouts to Team Red'>
# None
# red was Krizalid-i  blue was Dolphin
# red won
# fighters updated
# loop complete
# finish selection
# 160 regular 35,000 bet
# 1,385,188
# begin selection
# fighter 1 found
# fighter 2 found
# red ratio is 0.0
# blue ratio is 0.0
# bet on red
# go to loop
# loop start
# bet confirmed
# in a match
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
